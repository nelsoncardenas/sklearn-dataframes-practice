# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Data overview

# %%
df = pd.read_csv('./insurance_claims.csv')

# %% [markdown]
# ## General check

# %%
df.shape
# Out:
# (1000, 40)

# %%
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# ...

# %%
df.describe(include="all").iloc[:,0:11]
# Out:
#         months_as_customer          age  policy_number policy_bind_date  \
# count          1000.000000  1000.000000    1000.000000             1000
# unique                 NaN          NaN            NaN              951
# top                    NaN          NaN            NaN       2006-01-01
# freq                   NaN          NaN            NaN                3
# mean            203.954000    38.948000  546238.648000              NaN
# std             115.113174     9.140287  257063.005276              NaN
# min               0.000000    19.000000  100804.000000              NaN
# 25%             115.750000    32.000000  335980.250000              NaN
# 50%             199.500000    38.000000  533135.000000              NaN
# 75%             276.250000    44.000000  759099.750000              NaN
# max             479.000000    64.000000  999435.000000              NaN
#
#        policy_state policy_csl  policy_deductable  policy_annual_premium  \
# ...

# %%
df.describe(include="all").iloc[:,11:22]
# Out:
#        insured_education_level insured_occupation insured_hobbies  \
# count                     1000               1000            1000
# unique                       7                 14              20
# top                         JD  machine-op-inspct         reading
# freq                       161                 93              64
# mean                       NaN                NaN             NaN
# std                        NaN                NaN             NaN
# min                        NaN                NaN             NaN
# 25%                        NaN                NaN             NaN
# 50%                        NaN                NaN             NaN
# 75%                        NaN                NaN             NaN
# max                        NaN                NaN             NaN
#
#        insured_relationship  capital-gains   capital-loss incident_date  \
# count                  1000    1000.000000    1000.000000          1000
# ...

# %%
df.describe(include="all").iloc[:,22:32]
# Out:
#        incident_state incident_city incident_location  \
# count            1000          1000              1000
# unique              7             7              1000
# top                NY   Springfield    9935 4th Drive
# freq              262           157                 1
# mean              NaN           NaN               NaN
# std               NaN           NaN               NaN
# min               NaN           NaN               NaN
# 25%               NaN           NaN               NaN
# 50%               NaN           NaN               NaN
# 75%               NaN           NaN               NaN
# max               NaN           NaN               NaN
#
#         incident_hour_of_the_day  number_of_vehicles_involved property_damage  \
# count                1000.000000                   1000.00000            1000
# unique                       NaN                          NaN               3
# top                          NaN                          NaN               ?
# ...

# %%
df.describe(include="all").iloc[:,32:]
# Out:
#         injury_claim  property_claim  vehicle_claim auto_make auto_model  \
# count    1000.000000     1000.000000    1000.000000      1000       1000
# unique           NaN             NaN            NaN        14         39
# top              NaN             NaN            NaN      Saab        RAM
# freq             NaN             NaN            NaN        80         43
# mean     7433.420000     7399.570000   37928.950000       NaN        NaN
# std      4880.951853     4824.726179   18886.252893       NaN        NaN
# min         0.000000        0.000000      70.000000       NaN        NaN
# 25%      4295.000000     4445.000000   30292.500000       NaN        NaN
# 50%      6775.000000     6750.000000   42100.000000       NaN        NaN
# 75%     11305.000000    10885.000000   50822.500000       NaN        NaN
# max     21450.000000    23670.000000   79560.000000       NaN        NaN
#
#           auto_year fraud_reported  _c39
# count   1000.000000           1000   0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
# ...

# %% [markdown]
# ## Missing values

# %%
df.isna().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted             0
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# ...

# %% [markdown]
# ## Transformations plan
#
# 1. NaN correction: replace "?" for NaN.
# 2. Imputer: impute missing values mode and median.
# 3. Categorical encoder: OHE for categorical.
# 4. Scaler: standarization for numerical columns.
# 5. NaN handler: drop columns with more than 40% of NaNs.

# %%
df.replace("?", np.nan, inplace = True)

# %%
missing_vals = df.isna().sum().to_frame(name="num_nans")
nrows = df.shape[0]
missing_vals = missing_vals.assign(frac_nans = missing_vals["num_nans"]/nrows)
missing_vals
# Out:
#                              num_nans  frac_nans
# months_as_customer                  0      0.000
# age                                 0      0.000
# policy_number                       0      0.000
# policy_bind_date                    0      0.000
# policy_state                        0      0.000
# policy_csl                          0      0.000
# policy_deductable                   0      0.000
# policy_annual_premium               0      0.000
# umbrella_limit                      0      0.000
# insured_zip                         0      0.000
# insured_sex                         0      0.000
# insured_education_level             0      0.000
# insured_occupation                  0      0.000
# insured_hobbies                     0      0.000
# insured_relationship                0      0.000
# capital-gains                       0      0.000
# capital-loss                        0      0.000
# incident_date                       0      0.000
# ...

# %%
missing_vals[missing_vals["frac_nans"] >= 0.4].index.values.tolist()
# Out:
# ['_c39']

# %%
num_uniques = df.nunique().to_frame(name="num_uniques")
missing_vals = num_uniques.assign(
    frac_uniques=num_uniques["num_uniques"] / nrows
)
missing_vals = missing_vals[
    ~missing_vals.index.isin(["incident_date", "policy_bind_date"])
]
columns_to_drop = missing_vals[
    missing_vals["frac_uniques"] >= 0.9
].index.values.tolist()
columns_to_drop
# Out:
# ['policy_number', 'policy_annual_premium', 'insured_zip', 'incident_location']

# %%
df['collision_type'].mode()[0]

# %%
df['property_damage'].mode()[0]

# %%
df['police_report_available'].mode()[0]
